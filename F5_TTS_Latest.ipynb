# %%
# !nvcc --version
# https://pytorch.org/get-started/locally/
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install git+https://github.com/SWivid/F5-TTS.git
from IPython.display import clear_output
clear_output()

# %%
# !f5-tts_infer-gradio --share
# Out:
# Download Vocos from huggingface charactr/vocos-mel-24khz
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.yaml: 100% 461/461 [00:00<00:00, 2.90MB/s]
# pytorch_model.bin: 100% 54.4M/54.4M [00:00<00:00, 69.2MB/s]
# F5TTS_v1_Base/model_1250000.safetensors: 100% 1.35G/1.35G [00:08<00:00, 152MB/s]
#
# vocab :  /usr/local/lib/python3.12/dist-packages/f5_tts/infer/examples/vocab.txt
# token :  custom
# model :  /root/.cache/huggingface/hub/models--SWivid--F5-TTS/snapshots/84e5a410d9cead4de2f847e7c9369a6440bdfaca/F5TTS_v1_Base/model_1250000.safetensors
#
# Starting app...
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://f5c53e1991609e1634.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
